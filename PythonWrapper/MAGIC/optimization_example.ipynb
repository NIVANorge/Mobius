# %%
from importlib.machinery import SourceFileLoader

wr = SourceFileLoader("mobius", r"../mobius.py").load_module()
cu = SourceFileLoader("mobius_calib_uncert_lmfit", r"../mobius_calib_uncert_lmfit.py").load_module()

import magicopt

# %%
wr.initialize('../../Applications/MAGIC/magic_forest.dll')

parfile = '../../Applications/MAGIC/forest_test_parameters2.dat'
infile  = '../../Applications/MAGIC/forest_test_inputs.dat'

dataset = wr.DataSet.setup_from_parameter_and_input_files(parfile, infile)

dataset.run_model()  # to have some initial result values for comparison

idx = ('Soil1', 'Stream')

# %%
params, comparisons = magicopt.get_so4_setup(dataset, idx)

params
# Out:
# Parameters([('SO4half_S', <Parameter 'SO4half_S', 100.0, bounds=[0.0:1000.0]>),
#             ('SO4max_S', <Parameter 'SO4max_S', 0.1, bounds=[0.0:1.0]>),
#             ('WSO4_S', <Parameter 'WSO4_S', 20.0, bounds=[0.0:200.0]>)])

# %%
cu.print_goodness_of_fit(dataset, comparisons)
cu.plot_objective(dataset, comparisons)
# Out:
# Goodness of fit for SO4(2-) ionic concentration [Stream] vs Observed runoff conc SO4 []:
# Mean error (bias): -9.099585
# Mean absolute error: 10.805070
# Root mean square error: 16.441299
# Nash-Sutcliffe coefficient: 0.827856
# Number of observations: 42

# %%
res_pars = magicopt.calib(dataset, params, comparisons)

cu.print_goodness_of_fit(dataset, comparisons)
cu.plot_objective(dataset, comparisons)

res_pars
# Out:
# C:\Users\magnu\AppData\Roaming\Python\Python37\site-packages\numdifftools\limits.py:182: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   f_del = np.vstack(list(np.ravel(r)) for r in sequence)
# C:\Users\magnu\AppData\Roaming\Python\Python37\site-packages\numdifftools\limits.py:184: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for step in steps)
# Goodness of fit for SO4(2-) ionic concentration [Stream] vs Observed runoff conc SO4 []:
# Mean error (bias): -1.488405
# Mean absolute error: 10.507804
# Root mean square error: 14.142859
# Nash-Sutcliffe coefficient: 0.872622
# Number of observations: 42
# Parameters([('SO4half_S',
#              <Parameter 'SO4half_S', value=632.6258807617276 +/- 3.75e+05, bounds=[0.0:1000.0]>),
#             ('SO4max_S',
#              <Parameter 'SO4max_S', value=2.516124530949071e-10 +/- 1.17e-05, bounds=[0.0:1.0]>),
#             ('WSO4_S',
#              <Parameter 'WSO4_S', value=32.35609070747917 +/- 3.15, bounds=[0.0:200.0]>)])

# %%
params, comparisons = magicopt.get_base_cations_setup(dataset, idx)

params
# Out:
# WARNING: Parameter 'WMg_S' was initialised at the limit of its range. Gradient-based optimisers find this difficult.
#          Consider setting (min < value < max) instead?
# Parameters([('ECa_S', <Parameter 'ECa_S', 18.5, bounds=[1.0:25.0]>),
#             ('EMg_S', <Parameter 'EMg_S', 13.0, bounds=[1.0:25.0]>),
#             ('ENa_S', <Parameter 'ENa_S', 2.5, bounds=[1.0:25.0]>),
#             ('EK_S', <Parameter 'EK_S', 3.2, bounds=[1.0:25.0]>),
#             ('WCa_S', <Parameter 'WCa_S', 28.0, bounds=[0.0:200.0]>),
#             ('WMg_S', <Parameter 'WMg_S', 0.0, bounds=[0.0:200.0]>),
#             ('WNa_S', <Parameter 'WNa_S', 20.0, bounds=[0.0:200.0]>),
#             ('WK_S', <Parameter 'WK_S', 2.0, bounds=[0.0:200.0]>)])

# %%
cu.print_goodness_of_fit(dataset, comparisons)
cu.plot_objective(dataset, comparisons)
# Out:
# Goodness of fit for Ca(2+) ionic concentration [Stream] vs Observed runoff conc Ca []:
# Mean error (bias): 1.958212
# Mean absolute error: 5.116637
# Root mean square error: 6.209878
# Nash-Sutcliffe coefficient: 0.770166
# Number of observations: 42
#
#
# Goodness of fit for Mg(2+) ionic concentration [Stream] vs Observed runoff conc Mg []:
# Mean error (bias): 1.971728
# Mean absolute error: 3.020501
# Root mean square error: 3.733865
# Nash-Sutcliffe coefficient: 0.741265
# Number of observations: 42
#
#
# Goodness of fit for Na(+) ionic concentration [Stream] vs Observed runoff conc Na []:
# Mean error (bias): 2.066570
# Mean absolute error: 11.765283
# Root mean square error: 14.218768
# Nash-Sutcliffe coefficient: 0.065297
# Number of observations: 42
#
#
# Goodness of fit for K(+) ionic concentration [Stream] vs Observed runoff conc K []:
# Mean error (bias): 2.751735
# Mean absolute error: 3.008663
# Root mean square error: 3.262063
# Nash-Sutcliffe coefficient: -1.248380
# Number of observations: 42

# %%
res_pars = magicopt.calib(dataset, params, comparisons)

cu.print_goodness_of_fit(dataset, comparisons)
cu.plot_objective(dataset, comparisons)

res_pars
# Out:
# C:\Users\magnu\AppData\Roaming\Python\Python37\site-packages\numdifftools\limits.py:182: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   f_del = np.vstack(list(np.ravel(r)) for r in sequence)
# C:\Users\magnu\AppData\Roaming\Python\Python37\site-packages\numdifftools\limits.py:184: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for step in steps)
# C:\Program Files\Python37\lib\site-packages\lmfit\minimizer.py:789: RuntimeWarning: invalid value encountered in sqrt
#   (par.stderr * sqrt(self.result.covar[jvar, jvar])))
# C:\Program Files\Python37\lib\site-packages\lmfit\minimizer.py:782: RuntimeWarning: invalid value encountered in sqrt
#   par.stderr = sqrt(self.result.covar[ivar, ivar])
# Parameters([('ECa_S', <Parameter 'ECa_S', value=17.262946850990684 +/- 0.859, bounds=[1.0:25.0]>), ('EMg_S', <Parameter 'EMg_S', value=12.999011108783712 +/- 0.894, bounds=[1.0:25.0]>), ('ENa_S', <Parameter 'ENa_S', value=1.938622373626231 +/- 0.864, bounds=[1.0:25.0]>), ('EK_S', <Parameter 'EK_S', value=1.5639207598309568 +/- 0.0652, bounds=[1.0:25.0]>), ('WCa_S', <Parameter 'WCa_S', value=38.97793419668197 +/- nan, bounds=[0.0:200.0]>), ('WMg_S', <Parameter 'WMg_S', value=0.16073610640435776 +/- 0.919, bounds=[0.0:200.0]>), ('WNa_S', <Parameter 'WNa_S', value=25.460481001429525 +/- 1.69, bounds=[0.0:200.0]>), ('WK_S', <Parameter 'WK_S', value=0.013509944034595378 +/- 0.0662, bounds=[0.0:200.0]>)])
#
# Goodness of fit for Ca(2+) ionic concentration [Stream] vs Observed runoff conc Ca []:
# Mean error (bias): 0.386447
# Mean absolute error: 5.112087
# Root mean square error: 6.143609
# Nash-Sutcliffe coefficient: 0.775045
# Number of observations: 42
#
#
# Goodness of fit for Mg(2+) ionic concentration [Stream] vs Observed runoff conc Mg []:
# Mean error (bias): -0.035866
# Mean absolute error: 3.070130
# Root mean square error: 3.801491
# Nash-Sutcliffe coefficient: 0.731808
# Number of observations: 42
#
#
# Goodness of fit for Na(+) ionic concentration [Stream] vs Observed runoff conc Na []:
# Mean error (bias): 6.411002
# Mean absolute error: 12.967375
# Root mean square error: 16.329696
# Nash-Sutcliffe coefficient: -0.232838
# Number of observations: 42
#
#
# Goodness of fit for K(+) ionic concentration [Stream] vs Observed runoff conc K []:
# Mean error (bias): 0.112676
# Mean absolute error: 1.226647
# Root mean square error: 1.624985
# Nash-Sutcliffe coefficient: 0.442065
# Number of observations: 42
# Parameters([('ECa_S',
#              <Parameter 'ECa_S', value=17.262946850990684 +/- 0.859, bounds=[1.0:25.0]>),
#             ('EMg_S',
#              <Parameter 'EMg_S', value=12.999011108783712 +/- 0.894, bounds=[1.0:25.0]>),
#             ('ENa_S',
#              <Parameter 'ENa_S', value=1.938622373626231 +/- 0.864, bounds=[1.0:25.0]>),
#             ('EK_S',
#              <Parameter 'EK_S', value=1.5639207598309568 +/- 0.0652, bounds=[1.0:25.0]>),
#             ('WCa_S',
#              <Parameter 'WCa_S', value=38.97793419668197 +/- nan, bounds=[0.0:200.0]>),
#             ('WMg_S',
#              <Parameter 'WMg_S', value=0.16073610640435776 +/- 0.919, bounds=[0.0:200.0]>),
#             ('WNa_S',
#              <Parameter 'WNa_S', value=25.460481001429525 +/- 1.69, bounds=[0.0:200.0]>),
#             ('WK_S',
#              <Parameter 'WK_S', value=0.013509944034595378 +/- 0.0662, bounds=[0.0:200.0]>)])

# %%
params, comparisons = magicopt.get_doc_setup(dataset, idx)

params
# Out:
# Parameters([('OA_R', <Parameter 'OA_R', 25.0, bounds=[0.0:200.0]>)])

# %%
cu.print_goodness_of_fit(dataset, comparisons)
cu.plot_objective(dataset, comparisons)
# Out:
# Goodness of fit for pH [Stream] vs Observed runoff pH []:
# Mean error (bias): -0.021143
# Mean absolute error: 0.061739
# Root mean square error: 0.077030
# Nash-Sutcliffe coefficient: 0.387212
# Number of observations: 42

# %%
res_pars = magicopt.calib(dataset, params, comparisons)

cu.print_goodness_of_fit(dataset, comparisons)
cu.plot_objective(dataset, comparisons)

res_pars
# Out:
# C:\Users\magnu\AppData\Roaming\Python\Python37\site-packages\numdifftools\limits.py:182: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   f_del = np.vstack(list(np.ravel(r)) for r in sequence)
# C:\Users\magnu\AppData\Roaming\Python\Python37\site-packages\numdifftools\limits.py:184: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for step in steps)
# Parameters([('OA_R', <Parameter 'OA_R', value=21.90521412724654 +/- 1.37, bounds=[0.0:200.0]>)])
#
# Goodness of fit for pH [Stream] vs Observed runoff pH []:
# Mean error (bias): 0.001535
# Mean absolute error: 0.058013
# Root mean square error: 0.075584
# Nash-Sutcliffe coefficient: 0.410001
# Number of observations: 42
# Parameters([('OA_R',
#              <Parameter 'OA_R', value=21.90521412724654 +/- 1.37, bounds=[0.0:200.0]>)])

# %%
dataset.write_parameters_to_file('magicopt_best_params.dat')
